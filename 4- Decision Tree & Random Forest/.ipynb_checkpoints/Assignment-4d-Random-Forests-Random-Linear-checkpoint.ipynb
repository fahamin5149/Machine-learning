# %% [markdown]
# # Assignment No 4b
# ###### *Course Instructors: Dr. Hassan Raza, Mr. Ahmad Raza*
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests.For this part you will be implementing randomized version of **Randomized Linear** weak learner based Random Forest, i.e. you will be randomly selecting a pair of  features from all set of features and than randomly selecting the parameters for a generic equation of line,i.e. $ax+by+c=0$.
#
# ## TODO:
#
# **Complete the child class LinearWeakLearner in file `weaklearner.py` by writing the missing code.**
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## Submission Instructions
# You are required to submit the original notebook file on the google classroom (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
import numpy as np
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
cp = 5
nclasses = 2
mean1 = [-cp, -cp]
mean2 = [cp, cp]
mean3 = [cp, -cp]
mean4 = [-cp, cp]
cov = [[3.0, 0.0], [0.0, 3.0]]

# Create some points for the training set...
nexamples = 2000
x1 = np.random.multivariate_normal(mean1, cov, nexamples // 4)
x2 = np.random.multivariate_normal(mean2, cov, nexamples // 4)
x3 = np.random.multivariate_normal(mean3, cov, nexamples // 4)
x4 = np.random.multivariate_normal(mean4, cov, nexamples // 4)

X = np.vstack((x1, x2, x3, x4))
Y = np.vstack((1 * np.ones((nexamples // 4, 1)),
               2 * np.ones((nexamples // 4, 1)),
               3 * np.ones((nexamples // 4, 1)),
               4 * np.ones((nexamples // 4, 1))))

# Visualize the data
plt.scatter(x1[:, 0], x1[:, 1], c='r', s=100)
plt.scatter(x2[:, 0], x2[:, 1], c='g', s=100)
plt.scatter(x3[:, 0], x3[:, 1], c='b', s=100)
plt.scatter(x4[:, 0], x4[:, 1], c='y', s=100)

plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r', 'g', 'b', 'y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg', format='svg')

# Create some points for the test set
ntexamples = 1000
x1 = np.random.multivariate_normal(mean1, cov, ntexamples // 4)
x2 = np.random.multivariate_normal(mean2, cov, ntexamples // 4)
x3 = np.random.multivariate_normal(mean3, cov, ntexamples // 4)
x4 = np.random.multivariate_normal(mean4, cov, ntexamples // 4)

Xt = np.vstack((x1, x2, x3, x4))
Yt = np.vstack((1 * np.ones((ntexamples // 4, 1)),
                2 * np.ones((ntexamples // 4, 1)),
                3 * np.ones((ntexamples // 4, 1)),
                4 * np.ones((ntexamples // 4, 1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Linear')

# %%
print( X.shape, Y.shape)
# Out:
# (2000, 2) (2000, 1)

# %%
# %pdb
rfc.train(X,Y)
# Out:
# Automatic pdb calling has been turned ON

# %%
len(rfc.trees)
# Out:
# 10

# %%
# %pdb
# Training Confusion Matrix...
Yp=rfc.predict(X)
print (Y.shape, len(Yp))
t.print_confusion_matrix(Yp,Y)
# Out:
# Automatic pdb calling has been turned OFF
# (2000, 1) 2000
# C:\Users\user\Desktop\Files\University\ML\Assignment\A4\randomForest.py:179: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   final_predictions = mode(predictions, axis=0).mode[0]
# Predicted     1   All
# Actual
# 1.0         500   500
# 2.0         500   500
# 3.0         500   500
# 4.0         500   500
# All        2000  2000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y ==  np.array(Yp)) / float(Y.shape[0])

assert_greater_equal(acc, 0.78)

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-rlinear-10trees.svg',format='svg')
# Out:
# C:\Users\user\Desktop\Files\University\ML\Assignment\A4\randomForest.py:179: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   final_predictions = mode(predictions, axis=0).mode[0]
# C:\Users\user\Desktop\Files\University\ML\Assignment\A4\tools.py:699: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X[y==c, 0],

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print (Y.shape, len(Ypt))
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (2000, 1) 1000
# Predicted     1   All
# Actual
# 1.0         250   250
# 2.0         250   250
# 3.0         250   250
# 4.0         250   250
# All        1000  1000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y ==  np.array(Yp)) / float(Y.shape[0])

assert_greater_equal(acc, 0.78)

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')
# Out:
# C:\Users\user\Desktop\Files\University\ML\Assignment\A4\randomForest.py:179: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   final_predictions = mode(predictions, axis=0).mode[0]
# C:\Users\user\Desktop\Files\University\ML\Assignment\A4\tools.py:699: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X[y==c, 0],

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
# %pdb
t.plot_points_range(rfc,X,Y,10000)
# Out:
# Automatic pdb calling has been turned ON
# (10000, 2)
# [1.0, 2.0, 3.0, 4.0]

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 5
#       3 ncols=2
#       4 i=1
# ----> 5 plt.subplots(nrows,ncols,figsize=(16,20))
#       6 for tree in rfc.trees:
#       7     plt.subplot(nrows,ncols,i);
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1502, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1358 """
#    1359 Create a figure and a set of subplots.
#    1360
#    (...)
#    1499
#    1500 """
#    1501 fig = figure(**fig_kw)
# -> 1502 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1503                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1504                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1505                    width_ratios=width_ratios)
#    1506 return fig, axs
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\figure.py:905, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     901         raise ValueError("'width_ratios' must not be defined both as "
#     902                          "parameter and as key in 'gridspec_kw'")
#     903     gridspec_kw['width_ratios'] = width_ratios
# --> 905 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     906 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     907                   subplot_kw=subplot_kw)
#     908 return axs
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\figure.py:1527, in FigureBase.add_gridspec(self, nrows, ncols, **kwargs)
#    1488 """
#    1489 Return a `.GridSpec` that has this figure as a parent.  This allows
#    1490 complex layout of Axes in the figure.
#    (...)
#    1523
#    1524 """
#    1526 _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1527 gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1528 return gs
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\gridspec.py:379, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     376 self.hspace = hspace
#     377 self.figure = figure
# --> 379 super().__init__(nrows, ncols,
#     380                  width_ratios=width_ratios,
#     381                  height_ratios=height_ratios)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\gridspec.py:49, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      34 """
#      35 Parameters
#      36 ----------
#    (...)
#      46     If not given, all rows will have the same height.
#      47 """
#      48 if not isinstance(nrows, Integral) or nrows <= 0:
# ---> 49     raise ValueError(
#      50         f"Number of rows must be a positive integer, not {nrows!r}")
#      51 if not isinstance(ncols, Integral) or ncols <= 0:
#      52     raise ValueError(
#      53         f"Number of columns must be a positive integer, not {ncols!r}")
#
# ValueError: Number of rows must be a positive integer, not 5.0

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
print X.shape, Y.shape
# Out:
# (30000, 2) (30000,)

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Linear',usebagging=False,ntrees=20)
rfc.train(X,Y[:,np.newaxis])
# Out:
# Creating Left Child Node With 7616 Examples, and Right Node with 22384 Examples
# Creating Left Child Node With 3593 Examples, and Right Node with 4023 Examples
# Creating Left Child Node With 2384 Examples, and Right Node with 1209 Examples
# Creating Left Child Node With 1968 Examples, and Right Node with 416 Examples
# Creating Child Node With ClassLabel=0, nexamples=1968, classes=[(0, 1968)]
# Creating Child Node With ClassLabel=0, nexamples=416, classes=[(0, 403), (1, 13)]
# Creating Left Child Node With 696 Examples, and Right Node with 513 Examples
# Creating Child Node With ClassLabel=0, nexamples=696, classes=[(0, 696)]
# Creating Child Node With ClassLabel=1, nexamples=513, classes=[(1, 513)]
# Creating Left Child Node With 976 Examples, and Right Node with 3047 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 976 Examples
# Creating Child Node With ClassLabel=0, nexamples=976, classes=[(0, 976)]
# Creating Left Child Node With 6 Examples, and Right Node with 3041 Examples
# Creating Child Node With ClassLabel=0, nexamples=6, classes=[(0, 6)]
# Creating Child Node With ClassLabel=1, nexamples=3041, classes=[(0, 3), (1, 3038)]
# Creating Left Child Node With 13781 Examples, and Right Node with 8603 Examples
# Creating Left Child Node With 6442 Examples, and Right Node with 7339 Examples
# Creating Left Child Node With 3131 Examples, and Right Node with 3311 Examples
# Creating Child Node With ClassLabel=2, nexamples=3131, classes=[(0, 468), (1, 904), (2, 1759)]
# Creating Child Node With ClassLabel=0, nexamples=3311, classes=[(0, 2170), (1, 1140), (2, 1)]
# Creating Left Child Node With 1077 Examples, and Right Node with 6262 Examples
# Creating Child Node With ClassLabel=1, nexamples=1077, classes=[(1, 1077)]
# Creating Child Node With ClassLabel=1, nexamples=6262, classes=[(1, 3315), (2, 2947)]
# Creating Left Child Node With 3730 Examples, and Right Node with 4873 Examples
# Creating Left Child Node With 3534 Examples, and Right Node with 196 Examples
# Creating Child Node With ClassLabel=2, nexamples=3534, classes=[(2, 3534)]
# Creating Child Node With ClassLabel=0, nexamples=196, classes=[(0, 99), (2, 97)]
# Creating Left Child Node With 3046 Examples, and Right Node with 1827 Examples
# Creating Child Node With ClassLabel=0, nexamples=3046, classes=[(0, 3046)]
# Creating Child Node With ClassLabel=2, nexamples=1827, classes=[(0, 165), (2, 1662)]
# Creating Left Child Node With 16192 Examples, and Right Node with 13808 Examples
# Creating Left Child Node With 4011 Examples, and Right Node with 12181 Examples
# Creating Left Child Node With 3079 Examples, and Right Node with 932 Examples
# Creating Left Child Node With 751 Examples, and Right Node with 2328 Examples
# Creating Child Node With ClassLabel=1, nexamples=751, classes=[(1, 745), (2, 6)]
# Creating Child Node With ClassLabel=2, nexamples=2328, classes=[(2, 2328)]
# Creating Left Child Node With 286 Examples, and Right Node with 646 Examples
# Creating Child Node With ClassLabel=2, nexamples=286, classes=[(2, 286)]
# Creating Child Node With ClassLabel=1, nexamples=646, classes=[(1, 575), (2, 71)]
# Creating Left Child Node With 4173 Examples, and Right Node with 8008 Examples
# Creating Left Child Node With 578 Examples, and Right Node with 3595 Examples
# Creating Child Node With ClassLabel=1, nexamples=578, classes=[(1, 577), (2, 1)]
# Creating Child Node With ClassLabel=1, nexamples=3595, classes=[(1, 3595)]
# Creating Left Child Node With 4188 Examples, and Right Node with 3820 Examples
# Creating Child Node With ClassLabel=1, nexamples=4188, classes=[(0, 1101), (1, 2635), (2, 452)]
# Creating Child Node With ClassLabel=0, nexamples=3820, classes=[(0, 2884), (1, 746), (2, 190)]
# Creating Left Child Node With 12228 Examples, and Right Node with 1580 Examples
# Creating Left Child Node With 5035 Examples, and Right Node with 7193 Examples
# Creating Left Child Node With 1799 Examples, and Right Node with 3236 Examples
# Creating Child Node With ClassLabel=0, nexamples=1799, classes=[(0, 1799)]
# Creating Child Node With ClassLabel=2, nexamples=3236, classes=[(0, 772), (2, 2464)]
# Creating Left Child Node With 5443 Examples, and Right Node with 1750 Examples
# Creating Child Node With ClassLabel=2, nexamples=5443, classes=[(0, 2300), (2, 3143)]
# Creating Child Node With ClassLabel=2, nexamples=1750, classes=[(0, 6), (1, 685), (2, 1059)]
# Creating Left Child Node With 1209 Examples, and Right Node with 371 Examples
# Creating Left Child Node With 125 Examples, and Right Node with 1084 Examples
# Creating Child Node With ClassLabel=1, nexamples=125, classes=[(0, 54), (1, 71)]
# Creating Child Node With ClassLabel=0, nexamples=1084, classes=[(0, 1084)]
# Creating Left Child Node With 264 Examples, and Right Node with 107 Examples
# Creating Child Node With ClassLabel=1, nexamples=264, classes=[(1, 264)]
# Creating Child Node With ClassLabel=1, nexamples=107, classes=[(1, 107)]
# Creating Left Child Node With 21752 Examples, and Right Node with 8248 Examples
# Creating Left Child Node With 10735 Examples, and Right Node with 11017 Examples
# Creating Left Child Node With 4991 Examples, and Right Node with 5744 Examples
# Creating Left Child Node With 2915 Examples, and Right Node with 2076 Examples
# Creating Child Node With ClassLabel=0, nexamples=2915, classes=[(0, 1084), (1, 787), (2, 1044)]
# Creating Child Node With ClassLabel=1, nexamples=2076, classes=[(1, 2076)]
# Creating Left Child Node With 880 Examples, and Right Node with 4864 Examples
# Creating Child Node With ClassLabel=2, nexamples=880, classes=[(0, 150), (2, 730)]
# Creating Child Node With ClassLabel=0, nexamples=4864, classes=[(0, 3770), (1, 1093), (2, 1)]
# Creating Left Child Node With 2150 Examples, and Right Node with 8867 Examples
# Creating Left Child Node With 270 Examples, and Right Node with 1880 Examples
# Creating Child Node With ClassLabel=0, nexamples=270, classes=[(0, 270)]
# Creating Child Node With ClassLabel=0, nexamples=1880, classes=[(0, 1839), (1, 23), (2, 18)]
# Creating Left Child Node With 5982 Examples, and Right Node with 2885 Examples
# Creating Child Node With ClassLabel=2, nexamples=5982, classes=[(0, 42), (1, 141), (2, 5799)]
# Creating Child Node With ClassLabel=0, nexamples=2885, classes=[(0, 2718), (2, 167)]
# Creating Left Child Node With 2140 Examples, and Right Node with 6108 Examples
# Creating Left Child Node With 2140 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 685 Examples, and Right Node with 1455 Examples
# Creating Child Node With ClassLabel=2, nexamples=685, classes=[(2, 685)]
# Creating Child Node With ClassLabel=2, nexamples=1455, classes=[(2, 1455)]
# Creating Left Child Node With 3458 Examples, and Right Node with 2650 Examples
# Creating Left Child Node With 987 Examples, and Right Node with 2471 Examples
# Creating Child Node With ClassLabel=1, nexamples=987, classes=[(1, 987)]
# Creating Child Node With ClassLabel=1, nexamples=2471, classes=[(0, 127), (1, 2344)]
# Creating Left Child Node With 2317 Examples, and Right Node with 333 Examples
# Creating Child Node With ClassLabel=1, nexamples=2317, classes=[(1, 2317)]
# Creating Child Node With ClassLabel=1, nexamples=333, classes=[(1, 232), (2, 101)]
# Creating Left Child Node With 20712 Examples, and Right Node with 9288 Examples
# Creating Left Child Node With 13209 Examples, and Right Node with 7503 Examples
# Creating Left Child Node With 6424 Examples, and Right Node with 6785 Examples
# Creating Left Child Node With 5812 Examples, and Right Node with 612 Examples
# Creating Child Node With ClassLabel=2, nexamples=5812, classes=[(0, 2446), (1, 42), (2, 3324)]
# Creating Child Node With ClassLabel=1, nexamples=612, classes=[(1, 612)]
# Creating Left Child Node With 5011 Examples, and Right Node with 1774 Examples
# Creating Child Node With ClassLabel=1, nexamples=5011, classes=[(0, 78), (1, 4706), (2, 227)]
# Creating Child Node With ClassLabel=1, nexamples=1774, classes=[(0, 53), (1, 861), (2, 860)]
# Creating Left Child Node With 2742 Examples, and Right Node with 4761 Examples
# Creating Left Child Node With 2344 Examples, and Right Node with 398 Examples
# Creating Child Node With ClassLabel=2, nexamples=2344, classes=[(2, 2344)]
# Creating Child Node With ClassLabel=2, nexamples=398, classes=[(1, 73), (2, 325)]
# Creating Left Child Node With 981 Examples, and Right Node with 3780 Examples
# Creating Child Node With ClassLabel=0, nexamples=981, classes=[(0, 931), (2, 50)]
# Creating Child Node With ClassLabel=2, nexamples=3780, classes=[(0, 1168), (1, 1), (2, 2611)]
# Creating Left Child Node With 6145 Examples, and Right Node with 3143 Examples
# Creating Left Child Node With 5514 Examples, and Right Node with 631 Examples
# Creating Left Child Node With 1411 Examples, and Right Node with 4103 Examples
# Creating Child Node With ClassLabel=0, nexamples=1411, classes=[(0, 1152), (2, 259)]
# Creating Child Node With ClassLabel=0, nexamples=4103, classes=[(0, 3890), (1, 213)]
# Creating Left Child Node With 186 Examples, and Right Node with 445 Examples
# Creating Child Node With ClassLabel=1, nexamples=186, classes=[(0, 32), (1, 154)]
# Creating Child Node With ClassLabel=1, nexamples=445, classes=[(1, 445)]
# Creating Left Child Node With 2604 Examples, and Right Node with 539 Examples
# Creating Left Child Node With 217 Examples, and Right Node with 2387 Examples
# Creating Child Node With ClassLabel=0, nexamples=217, classes=[(0, 217)]
# Creating Child Node With ClassLabel=1, nexamples=2387, classes=[(0, 33), (1, 2354)]
# Creating Left Child Node With 0 Examples, and Right Node with 539 Examples
# Creating Child Node With ClassLabel=1, nexamples=539, classes=[(1, 539)]
# Creating Left Child Node With 8253 Examples, and Right Node with 21747 Examples
# Creating Left Child Node With 6828 Examples, and Right Node with 1425 Examples
# Creating Left Child Node With 5312 Examples, and Right Node with 1516 Examples
# Creating Left Child Node With 2108 Examples, and Right Node with 3204 Examples
# Creating Child Node With ClassLabel=2, nexamples=2108, classes=[(0, 222), (2, 1886)]
# Creating Child Node With ClassLabel=0, nexamples=3204, classes=[(0, 2514), (2, 690)]
# Creating Left Child Node With 319 Examples, and Right Node with 1197 Examples
# Creating Child Node With ClassLabel=0, nexamples=319, classes=[(0, 319)]
# Creating Child Node With ClassLabel=0, nexamples=1197, classes=[(0, 1178), (1, 16), (2, 3)]
# Creating Left Child Node With 1414 Examples, and Right Node with 11 Examples
# Creating Left Child Node With 1090 Examples, and Right Node with 324 Examples
# Creating Child Node With ClassLabel=2, nexamples=1090, classes=[(0, 182), (2, 908)]
# Creating Child Node With ClassLabel=2, nexamples=324, classes=[(2, 324)]
# Creating Left Child Node With 11 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=11, classes=[(2, 11)]
# Creating Left Child Node With 8058 Examples, and Right Node with 13689 Examples
# Creating Left Child Node With 4260 Examples, and Right Node with 3798 Examples
# Creating Left Child Node With 2242 Examples, and Right Node with 2018 Examples
# Creating Child Node With ClassLabel=2, nexamples=2242, classes=[(1, 240), (2, 2002)]
# Creating Child Node With ClassLabel=2, nexamples=2018, classes=[(1, 839), (2, 1179)]
# Creating Left Child Node With 696 Examples, and Right Node with 3102 Examples
# Creating Child Node With ClassLabel=1, nexamples=696, classes=[(1, 683), (2, 13)]
# Creating Child Node With ClassLabel=1, nexamples=3102, classes=[(1, 3102)]
# Creating Left Child Node With 10021 Examples, and Right Node with 3668 Examples
# Creating Left Child Node With 4103 Examples, and Right Node with 5918 Examples
# Creating Child Node With ClassLabel=2, nexamples=4103, classes=[(0, 700), (1, 593), (2, 2810)]
# Creating Child Node With ClassLabel=0, nexamples=5918, classes=[(0, 4825), (1, 920), (2, 173)]
# Creating Left Child Node With 1059 Examples, and Right Node with 2609 Examples
# Creating Child Node With ClassLabel=1, nexamples=1059, classes=[(0, 60), (1, 999)]
# Creating Child Node With ClassLabel=1, nexamples=2609, classes=[(1, 2608), (2, 1)]
# Creating Left Child Node With 7670 Examples, and Right Node with 22330 Examples
# Creating Left Child Node With 3515 Examples, and Right Node with 4155 Examples
# Creating Left Child Node With 1828 Examples, and Right Node with 1687 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1828 Examples
# Creating Child Node With ClassLabel=2, nexamples=1828, classes=[(2, 1828)]
# Creating Left Child Node With 557 Examples, and Right Node with 1130 Examples
# Creating Child Node With ClassLabel=1, nexamples=557, classes=[(1, 557)]
# Creating Child Node With ClassLabel=1, nexamples=1130, classes=[(1, 1106), (2, 24)]
# Creating Left Child Node With 64 Examples, and Right Node with 4091 Examples
# Creating Left Child Node With 64 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=64, classes=[(1, 5), (2, 59)]
# Creating Left Child Node With 2491 Examples, and Right Node with 1600 Examples
# Creating Child Node With ClassLabel=1, nexamples=2491, classes=[(1, 2491)]
# Creating Child Node With ClassLabel=1, nexamples=1600, classes=[(0, 60), (1, 1540)]
# Creating Left Child Node With 18584 Examples, and Right Node with 3746 Examples
# Creating Left Child Node With 8744 Examples, and Right Node with 9840 Examples
# Creating Left Child Node With 5728 Examples, and Right Node with 3016 Examples
# Creating Child Node With ClassLabel=1, nexamples=5728, classes=[(0, 4), (1, 3130), (2, 2594)]
# Creating Child Node With ClassLabel=2, nexamples=3016, classes=[(0, 59), (1, 1), (2, 2956)]
# Creating Left Child Node With 5174 Examples, and Right Node with 4666 Examples
# Creating Child Node With ClassLabel=0, nexamples=5174, classes=[(0, 4081), (1, 929), (2, 164)]
# Creating Child Node With ClassLabel=2, nexamples=4666, classes=[(0, 2104), (1, 234), (2, 2328)]
# Creating Left Child Node With 2771 Examples, and Right Node with 975 Examples
# Creating Left Child Node With 826 Examples, and Right Node with 1945 Examples
# Creating Child Node With ClassLabel=0, nexamples=826, classes=[(0, 826)]
# Creating Child Node With ClassLabel=0, nexamples=1945, classes=[(0, 1898), (2, 47)]
# Creating Left Child Node With 968 Examples, and Right Node with 7 Examples
# Creating Child Node With ClassLabel=0, nexamples=968, classes=[(0, 967), (1, 1)]
# Creating Child Node With ClassLabel=1, nexamples=7, classes=[(0, 1), (1, 6)]
# Creating Left Child Node With 7287 Examples, and Right Node with 22713 Examples
# Creating Left Child Node With 2100 Examples, and Right Node with 5187 Examples
# Creating Left Child Node With 1469 Examples, and Right Node with 631 Examples
# Creating Left Child Node With 929 Examples, and Right Node with 540 Examples
# Creating Child Node With ClassLabel=2, nexamples=929, classes=[(2, 929)]
# Creating Child Node With ClassLabel=2, nexamples=540, classes=[(2, 540)]
# Creating Left Child Node With 611 Examples, and Right Node with 20 Examples
# Creating Child Node With ClassLabel=2, nexamples=611, classes=[(1, 3), (2, 608)]
# Creating Child Node With ClassLabel=1, nexamples=20, classes=[(1, 20)]
# Creating Left Child Node With 2947 Examples, and Right Node with 2240 Examples
# Creating Left Child Node With 813 Examples, and Right Node with 2134 Examples
# Creating Child Node With ClassLabel=1, nexamples=813, classes=[(1, 813)]
# Creating Child Node With ClassLabel=1, nexamples=2134, classes=[(1, 2134)]
# Creating Left Child Node With 2237 Examples, and Right Node with 3 Examples
# Creating Child Node With ClassLabel=1, nexamples=2237, classes=[(1, 2193), (2, 44)]
# Creating Child Node With ClassLabel=2, nexamples=3, classes=[(1, 1), (2, 2)]
# Creating Left Child Node With 12180 Examples, and Right Node with 10533 Examples
# Creating Left Child Node With 8081 Examples, and Right Node with 4099 Examples
# Creating Left Child Node With 504 Examples, and Right Node with 7577 Examples
# Creating Child Node With ClassLabel=0, nexamples=504, classes=[(0, 504)]
# Creating Child Node With ClassLabel=2, nexamples=7577, classes=[(0, 1413), (1, 47), (2, 6117)]
# Creating Left Child Node With 3803 Examples, and Right Node with 296 Examples
# Creating Child Node With ClassLabel=0, nexamples=3803, classes=[(0, 3788), (1, 14), (2, 1)]
# Creating Child Node With ClassLabel=1, nexamples=296, classes=[(1, 296)]
# Creating Left Child Node With 6139 Examples, and Right Node with 4394 Examples
# Creating Left Child Node With 2458 Examples, and Right Node with 3681 Examples
# Creating Child Node With ClassLabel=1, nexamples=2458, classes=[(0, 1), (1, 1860), (2, 597)]
# Creating Child Node With ClassLabel=1, nexamples=3681, classes=[(0, 1034), (1, 1485), (2, 1162)]
# Creating Left Child Node With 1134 Examples, and Right Node with 3260 Examples
# Creating Child Node With ClassLabel=1, nexamples=1134, classes=[(1, 1134)]
# Creating Child Node With ClassLabel=0, nexamples=3260, classes=[(0, 3260)]
# Creating Left Child Node With 8251 Examples, and Right Node with 21749 Examples
# Creating Left Child Node With 2257 Examples, and Right Node with 5994 Examples
# Creating Left Child Node With 2257 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 721 Examples, and Right Node with 1536 Examples
# Creating Child Node With ClassLabel=1, nexamples=721, classes=[(1, 721)]
# Creating Child Node With ClassLabel=1, nexamples=1536, classes=[(1, 1536)]
# Creating Left Child Node With 2174 Examples, and Right Node with 3820 Examples
# Creating Left Child Node With 2023 Examples, and Right Node with 151 Examples
# Creating Child Node With ClassLabel=1, nexamples=2023, classes=[(1, 2019), (2, 4)]
# Creating Child Node With ClassLabel=0, nexamples=151, classes=[(0, 132), (1, 19)]
# Creating Left Child Node With 2321 Examples, and Right Node with 1499 Examples
# Creating Child Node With ClassLabel=2, nexamples=2321, classes=[(1, 125), (2, 2196)]
# Creating Child Node With ClassLabel=1, nexamples=1499, classes=[(1, 1474), (2, 25)]
# Creating Left Child Node With 10875 Examples, and Right Node with 10874 Examples
# Creating Left Child Node With 4283 Examples, and Right Node with 6592 Examples
# Creating Left Child Node With 3969 Examples, and Right Node with 314 Examples
# Creating Child Node With ClassLabel=0, nexamples=3969, classes=[(0, 3905), (2, 64)]
# Creating Child Node With ClassLabel=0, nexamples=314, classes=[(0, 278), (1, 36)]
# Creating Left Child Node With 5692 Examples, and Right Node with 900 Examples
# Creating Child Node With ClassLabel=2, nexamples=5692, classes=[(0, 207), (1, 28), (2, 5457)]
# Creating Child Node With ClassLabel=0, nexamples=900, classes=[(0, 526), (2, 374)]
# Creating Left Child Node With 8397 Examples, and Right Node with 2477 Examples
# Creating Left Child Node With 7212 Examples, and Right Node with 1185 Examples
# Creating Child Node With ClassLabel=0, nexamples=7212, classes=[(0, 4818), (1, 554), (2, 1840)]
# Creating Child Node With ClassLabel=1, nexamples=1185, classes=[(0, 134), (1, 1051)]
# Creating Left Child Node With 40 Examples, and Right Node with 2437 Examples
# Creating Child Node With ClassLabel=2, nexamples=40, classes=[(2, 40)]
# Creating Child Node With ClassLabel=1, nexamples=2437, classes=[(1, 2437)]
# Creating Left Child Node With 9108 Examples, and Right Node with 20892 Examples
# Creating Left Child Node With 6835 Examples, and Right Node with 2273 Examples
# Creating Left Child Node With 5874 Examples, and Right Node with 961 Examples
# Creating Left Child Node With 4105 Examples, and Right Node with 1769 Examples
# Creating Child Node With ClassLabel=0, nexamples=4105, classes=[(0, 3532), (1, 447), (2, 126)]
# Creating Child Node With ClassLabel=0, nexamples=1769, classes=[(0, 1712), (2, 57)]
# Creating Left Child Node With 0 Examples, and Right Node with 961 Examples
# Creating Child Node With ClassLabel=1, nexamples=961, classes=[(1, 961)]
# Creating Left Child Node With 289 Examples, and Right Node with 1984 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 289 Examples
# Creating Child Node With ClassLabel=1, nexamples=289, classes=[(1, 289)]
# Creating Left Child Node With 342 Examples, and Right Node with 1642 Examples
# Creating Child Node With ClassLabel=1, nexamples=342, classes=[(1, 342)]
# Creating Child Node With ClassLabel=1, nexamples=1642, classes=[(1, 1642)]
# Creating Left Child Node With 9186 Examples, and Right Node with 11706 Examples
# Creating Left Child Node With 7078 Examples, and Right Node with 2108 Examples
# Creating Left Child Node With 5176 Examples, and Right Node with 1902 Examples
# Creating Child Node With ClassLabel=2, nexamples=5176, classes=[(0, 765), (2, 4411)]
# Creating Child Node With ClassLabel=0, nexamples=1902, classes=[(0, 1902)]
# Creating Left Child Node With 578 Examples, and Right Node with 1530 Examples
# Creating Child Node With ClassLabel=2, nexamples=578, classes=[(2, 578)]
# Creating Child Node With ClassLabel=2, nexamples=1530, classes=[(1, 294), (2, 1236)]
# Creating Left Child Node With 6368 Examples, and Right Node with 5338 Examples
# Creating Left Child Node With 2710 Examples, and Right Node with 3658 Examples
# Creating Child Node With ClassLabel=2, nexamples=2710, classes=[(1, 527), (2, 2183)]
# Creating Child Node With ClassLabel=1, nexamples=3658, classes=[(1, 3184), (2, 474)]
# Creating Left Child Node With 2268 Examples, and Right Node with 3070 Examples
# Creating Child Node With ClassLabel=1, nexamples=2268, classes=[(0, 232), (1, 1102), (2, 934)]
# Creating Child Node With ClassLabel=0, nexamples=3070, classes=[(0, 1857), (1, 1212), (2, 1)]
# Creating Left Child Node With 19735 Examples, and Right Node with 10265 Examples
# Creating Left Child Node With 8717 Examples, and Right Node with 11018 Examples
# Creating Left Child Node With 5957 Examples, and Right Node with 2760 Examples
# Creating Left Child Node With 4882 Examples, and Right Node with 1075 Examples
# Creating Child Node With ClassLabel=1, nexamples=4882, classes=[(0, 2396), (1, 2485), (2, 1)]
# Creating Child Node With ClassLabel=0, nexamples=1075, classes=[(0, 1075)]
# Creating Left Child Node With 2639 Examples, and Right Node with 121 Examples
# Creating Child Node With ClassLabel=1, nexamples=2639, classes=[(0, 3), (1, 2613), (2, 23)]
# Creating Child Node With ClassLabel=2, nexamples=121, classes=[(2, 121)]
# Creating Left Child Node With 2912 Examples, and Right Node with 8106 Examples
# Creating Left Child Node With 1367 Examples, and Right Node with 1545 Examples
# Creating Child Node With ClassLabel=2, nexamples=1367, classes=[(2, 1367)]
# Creating Child Node With ClassLabel=0, nexamples=1545, classes=[(0, 941), (2, 604)]
# Creating Left Child Node With 4396 Examples, and Right Node with 3710 Examples
# Creating Child Node With ClassLabel=1, nexamples=4396, classes=[(0, 385), (1, 3443), (2, 568)]
# Creating Child Node With ClassLabel=2, nexamples=3710, classes=[(1, 1303), (2, 2407)]
# Creating Left Child Node With 3766 Examples, and Right Node with 6499 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 3758 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1, nexamples=8, classes=[(1, 8)]
# Creating Left Child Node With 2247 Examples, and Right Node with 1511 Examples
# Creating Child Node With ClassLabel=0, nexamples=2247, classes=[(0, 2193), (2, 54)]
# Creating Child Node With ClassLabel=0, nexamples=1511, classes=[(0, 1511)]
# Creating Left Child Node With 1436 Examples, and Right Node with 5063 Examples
# Creating Left Child Node With 558 Examples, and Right Node with 878 Examples
# Creating Child Node With ClassLabel=0, nexamples=558, classes=[(0, 410), (1, 148)]
# Creating Child Node With ClassLabel=0, nexamples=878, classes=[(0, 878)]
# Creating Left Child Node With 262 Examples, and Right Node with 4801 Examples
# Creating Child Node With ClassLabel=0, nexamples=262, classes=[(0, 153), (2, 109)]
# Creating Child Node With ClassLabel=2, nexamples=4801, classes=[(0, 55), (2, 4746)]
# Creating Left Child Node With 21606 Examples, and Right Node with 8394 Examples
# Creating Left Child Node With 13134 Examples, and Right Node with 8472 Examples
# Creating Left Child Node With 4589 Examples, and Right Node with 8545 Examples
# Creating Left Child Node With 4242 Examples, and Right Node with 347 Examples
# Creating Child Node With ClassLabel=0, nexamples=4242, classes=[(0, 4212), (1, 28), (2, 2)]
# Creating Child Node With ClassLabel=1, nexamples=347, classes=[(1, 347)]
# Creating Left Child Node With 4446 Examples, and Right Node with 4099 Examples
# Creating Child Node With ClassLabel=2, nexamples=4446, classes=[(0, 1649), (1, 303), (2, 2494)]
# Creating Child Node With ClassLabel=2, nexamples=4099, classes=[(0, 58), (1, 477), (2, 3564)]
# Creating Left Child Node With 6893 Examples, and Right Node with 1579 Examples
# Creating Left Child Node With 4300 Examples, and Right Node with 2593 Examples
# Creating Child Node With ClassLabel=0, nexamples=4300, classes=[(0, 3767), (1, 533)]
# Creating Child Node With ClassLabel=1, nexamples=2593, classes=[(0, 305), (1, 1597), (2, 691)]
# Creating Left Child Node With 0 Examples, and Right Node with 1579 Examples
# Creating Child Node With ClassLabel=1, nexamples=1579, classes=[(1, 1579)]
# Creating Left Child Node With 5625 Examples, and Right Node with 2769 Examples
# Creating Left Child Node With 4385 Examples, and Right Node with 1240 Examples
# Creating Left Child Node With 1232 Examples, and Right Node with 3153 Examples
# Creating Child Node With ClassLabel=1, nexamples=1232, classes=[(1, 1232)]
# Creating Child Node With ClassLabel=1, nexamples=3153, classes=[(1, 3153)]
# Creating Left Child Node With 624 Examples, and Right Node with 616 Examples
# Creating Child Node With ClassLabel=2, nexamples=624, classes=[(0, 8), (2, 616)]
# Creating Child Node With ClassLabel=1, nexamples=616, classes=[(1, 616)]
# Creating Left Child Node With 534 Examples, and Right Node with 2235 Examples
# Creating Left Child Node With 476 Examples, and Right Node with 58 Examples
# Creating Child Node With ClassLabel=2, nexamples=476, classes=[(1, 80), (2, 396)]
# Creating Child Node With ClassLabel=1, nexamples=58, classes=[(1, 55), (2, 3)]
# Creating Left Child Node With 16 Examples, and Right Node with 2219 Examples
# Creating Child Node With ClassLabel=2, nexamples=16, classes=[(0, 1), (2, 15)]
# Creating Child Node With ClassLabel=2, nexamples=2219, classes=[(2, 2219)]
# Creating Left Child Node With 20715 Examples, and Right Node with 9285 Examples
# Creating Left Child Node With 17466 Examples, and Right Node with 3249 Examples
# Creating Left Child Node With 5353 Examples, and Right Node with 12113 Examples
# Creating Left Child Node With 3632 Examples, and Right Node with 1721 Examples
# Creating Child Node With ClassLabel=1, nexamples=3632, classes=[(1, 3632)]
# Creating Child Node With ClassLabel=1, nexamples=1721, classes=[(1, 1636), (2, 85)]
# Creating Left Child Node With 5845 Examples, and Right Node with 6268 Examples
# Creating Child Node With ClassLabel=0, nexamples=5845, classes=[(0, 2610), (1, 806), (2, 2429)]
# Creating Child Node With ClassLabel=1, nexamples=6268, classes=[(0, 2453), (1, 3815)]
# Creating Left Child Node With 3249 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 2051 Examples, and Right Node with 1198 Examples
# Creating Child Node With ClassLabel=2, nexamples=2051, classes=[(2, 2051)]
# Creating Child Node With ClassLabel=2, nexamples=1198, classes=[(2, 1198)]
# Creating Left Child Node With 5191 Examples, and Right Node with 4094 Examples
# Creating Left Child Node With 1304 Examples, and Right Node with 3887 Examples
# Creating Left Child Node With 22 Examples, and Right Node with 1282 Examples
# Creating Child Node With ClassLabel=1, nexamples=22, classes=[(1, 22)]
# Creating Child Node With ClassLabel=0, nexamples=1282, classes=[(0, 1192), (1, 89), (2, 1)]
# Creating Left Child Node With 2001 Examples, and Right Node with 1886 Examples
# Creating Child Node With ClassLabel=0, nexamples=2001, classes=[(0, 1423), (2, 578)]
# Creating Child Node With ClassLabel=0, nexamples=1886, classes=[(0, 1886)]
# Creating Left Child Node With 3802 Examples, and Right Node with 292 Examples
# Creating Left Child Node With 2380 Examples, and Right Node with 1422 Examples
# Creating Child Node With ClassLabel=2, nexamples=2380, classes=[(0, 11), (2, 2369)]
# Creating Child Node With ClassLabel=2, nexamples=1422, classes=[(0, 133), (2, 1289)]
# Creating Left Child Node With 292 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=292, classes=[(0, 292)]
# Creating Left Child Node With 22359 Examples, and Right Node with 7641 Examples
# Creating Left Child Node With 18867 Examples, and Right Node with 3492 Examples
# Creating Left Child Node With 13152 Examples, and Right Node with 5715 Examples
# Creating Left Child Node With 1082 Examples, and Right Node with 12070 Examples
# Creating Child Node With ClassLabel=1, nexamples=1082, classes=[(0, 146), (1, 936)]
# Creating Child Node With ClassLabel=0, nexamples=12070, classes=[(0, 6222), (1, 1442), (2, 4406)]
# Creating Left Child Node With 2779 Examples, and Right Node with 2936 Examples
# Creating Child Node With ClassLabel=1, nexamples=2779, classes=[(1, 1740), (2, 1039)]
# Creating Child Node With ClassLabel=2, nexamples=2936, classes=[(0, 94), (1, 201), (2, 2641)]
# Creating Left Child Node With 5 Examples, and Right Node with 3487 Examples
# Creating Child Node With ClassLabel=1, nexamples=5, classes=[(0, 2), (1, 3)]
# Creating Left Child Node With 1637 Examples, and Right Node with 1850 Examples
# Creating Child Node With ClassLabel=0, nexamples=1637, classes=[(0, 1637)]
# Creating Child Node With ClassLabel=0, nexamples=1850, classes=[(0, 1844), (2, 6)]
# Creating Left Child Node With 3675 Examples, and Right Node with 3966 Examples
# Creating Left Child Node With 597 Examples, and Right Node with 3078 Examples
# Creating Left Child Node With 188 Examples, and Right Node with 409 Examples
# Creating Child Node With ClassLabel=1, nexamples=188, classes=[(1, 187), (2, 1)]
# Creating Child Node With ClassLabel=1, nexamples=409, classes=[(1, 409)]
# Creating Left Child Node With 34 Examples, and Right Node with 3044 Examples
# Creating Child Node With ClassLabel=0, nexamples=34, classes=[(0, 34)]
# Creating Child Node With ClassLabel=1, nexamples=3044, classes=[(0, 21), (1, 3023)]
# Creating Left Child Node With 2119 Examples, and Right Node with 1847 Examples
# Creating Left Child Node With 1242 Examples, and Right Node with 877 Examples
# Creating Child Node With ClassLabel=1, nexamples=1242, classes=[(1, 1181), (2, 61)]
# Creating Child Node With ClassLabel=1, nexamples=877, classes=[(1, 877)]
# Creating Left Child Node With 1831 Examples, and Right Node with 16 Examples
# Creating Child Node With ClassLabel=2, nexamples=1831, classes=[(2, 1831)]
# Creating Child Node With ClassLabel=2, nexamples=16, classes=[(1, 1), (2, 15)]
# Creating Left Child Node With 21452 Examples, and Right Node with 8548 Examples
# Creating Left Child Node With 4899 Examples, and Right Node with 16553 Examples
# Creating Left Child Node With 2281 Examples, and Right Node with 2618 Examples
# Creating Left Child Node With 572 Examples, and Right Node with 1709 Examples
# Creating Child Node With ClassLabel=2, nexamples=572, classes=[(0, 141), (2, 431)]
# Creating Child Node With ClassLabel=2, nexamples=1709, classes=[(2, 1709)]
# Creating Left Child Node With 976 Examples, and Right Node with 1642 Examples
# Creating Child Node With ClassLabel=0, nexamples=976, classes=[(0, 976)]
# Creating Child Node With ClassLabel=0, nexamples=1642, classes=[(0, 1641), (2, 1)]
# Creating Left Child Node With 12929 Examples, and Right Node with 3624 Examples
# Creating Left Child Node With 6365 Examples, and Right Node with 6564 Examples
# Creating Child Node With ClassLabel=1, nexamples=6365, classes=[(0, 13), (1, 5538), (2, 814)]
# Creating Child Node With ClassLabel=2, nexamples=6564, classes=[(0, 2274), (1, 893), (2, 3397)]
# Creating Left Child Node With 2357 Examples, and Right Node with 1267 Examples
# Creating Child Node With ClassLabel=2, nexamples=2357, classes=[(2, 2357)]
# Creating Child Node With ClassLabel=2, nexamples=1267, classes=[(0, 6), (2, 1261)]
# Creating Left Child Node With 2443 Examples, and Right Node with 6105 Examples
# Creating Left Child Node With 1124 Examples, and Right Node with 1319 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1124 Examples
# Creating Child Node With ClassLabel=1, nexamples=1124, classes=[(1, 1124)]
# Creating Left Child Node With 1319 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1, nexamples=1319, classes=[(1, 1319)]
# Creating Left Child Node With 1944 Examples, and Right Node with 4161 Examples
# Creating Left Child Node With 1505 Examples, and Right Node with 439 Examples
# Creating Child Node With ClassLabel=0, nexamples=1505, classes=[(0, 1503), (1, 2)]
# Creating Child Node With ClassLabel=0, nexamples=439, classes=[(0, 410), (2, 29)]
# Creating Left Child Node With 2736 Examples, and Right Node with 1425 Examples
# Creating Child Node With ClassLabel=0, nexamples=2736, classes=[(0, 1628), (1, 1108)]
# Creating Child Node With ClassLabel=0, nexamples=1425, classes=[(0, 1408), (1, 16), (2, 1)]
# Creating Left Child Node With 19664 Examples, and Right Node with 10336 Examples
# Creating Left Child Node With 17545 Examples, and Right Node with 2119 Examples
# Creating Left Child Node With 13397 Examples, and Right Node with 4148 Examples
# Creating Left Child Node With 8912 Examples, and Right Node with 4485 Examples
# Creating Child Node With ClassLabel=0, nexamples=8912, classes=[(0, 5042), (1, 1835), (2, 2035)]
# Creating Child Node With ClassLabel=1, nexamples=4485, classes=[(1, 4484), (2, 1)]
# Creating Left Child Node With 1750 Examples, and Right Node with 2398 Examples
# Creating Child Node With ClassLabel=1, nexamples=1750, classes=[(1, 1204), (2, 546)]
# Creating Child Node With ClassLabel=1, nexamples=2398, classes=[(1, 2398)]
# Creating Left Child Node With 14 Examples, and Right Node with 2105 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 14 Examples
# Creating Child Node With ClassLabel=1, nexamples=14, classes=[(1, 14)]
# Creating Left Child Node With 437 Examples, and Right Node with 1668 Examples
# Creating Child Node With ClassLabel=2, nexamples=437, classes=[(2, 437)]
# Creating Child Node With ClassLabel=2, nexamples=1668, classes=[(2, 1668)]
# Creating Left Child Node With 1296 Examples, and Right Node with 9040 Examples
# Creating Left Child Node With 1149 Examples, and Right Node with 147 Examples
# Creating Left Child Node With 111 Examples, and Right Node with 1038 Examples
# Creating Child Node With ClassLabel=0, nexamples=111, classes=[(0, 110), (1, 1)]
# Creating Child Node With ClassLabel=0, nexamples=1038, classes=[(0, 974), (1, 64)]
# Creating Left Child Node With 147 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=147, classes=[(0, 147)]
# Creating Left Child Node With 6799 Examples, and Right Node with 2241 Examples
# Creating Left Child Node With 4151 Examples, and Right Node with 2648 Examples
# Creating Child Node With ClassLabel=2, nexamples=4151, classes=[(0, 1727), (2, 2424)]
# Creating Child Node With ClassLabel=0, nexamples=2648, classes=[(0, 1661), (2, 987)]
# Creating Left Child Node With 1865 Examples, and Right Node with 376 Examples
# Creating Child Node With ClassLabel=2, nexamples=1865, classes=[(0, 17), (2, 1848)]
# Creating Child Node With ClassLabel=0, nexamples=376, classes=[(0, 322), (2, 54)]
# Creating Left Child Node With 20916 Examples, and Right Node with 9084 Examples
# Creating Left Child Node With 1511 Examples, and Right Node with 19405 Examples
# Creating Left Child Node With 141 Examples, and Right Node with 1370 Examples
# Creating Left Child Node With 13 Examples, and Right Node with 128 Examples
# Creating Child Node With ClassLabel=1, nexamples=13, classes=[(1, 13)]
# Creating Child Node With ClassLabel=2, nexamples=128, classes=[(2, 128)]
# Creating Left Child Node With 0 Examples, and Right Node with 1370 Examples
# Creating Child Node With ClassLabel=2, nexamples=1370, classes=[(2, 1370)]
# Creating Left Child Node With 6634 Examples, and Right Node with 12771 Examples
# Creating Left Child Node With 3651 Examples, and Right Node with 2983 Examples
# Creating Child Node With ClassLabel=1, nexamples=3651, classes=[(1, 3601), (2, 50)]
# Creating Child Node With ClassLabel=1, nexamples=2983, classes=[(0, 485), (1, 2498)]
# Creating Left Child Node With 3730 Examples, and Right Node with 9041 Examples
# Creating Child Node With ClassLabel=1, nexamples=3730, classes=[(0, 1320), (1, 2410)]
# Creating Child Node With ClassLabel=0, nexamples=9041, classes=[(0, 4520), (1, 1477), (2, 3044)]
# Creating Left Child Node With 5842 Examples, and Right Node with 3242 Examples
# Creating Left Child Node With 4767 Examples, and Right Node with 1075 Examples
# Creating Left Child Node With 3513 Examples, and Right Node with 1254 Examples
# Creating Child Node With ClassLabel=2, nexamples=3513, classes=[(0, 138), (2, 3375)]
# Creating Child Node With ClassLabel=2, nexamples=1254, classes=[(1, 1), (2, 1253)]
# Creating Left Child Node With 295 Examples, and Right Node with 780 Examples
# Creating Child Node With ClassLabel=0, nexamples=295, classes=[(0, 295)]
# Creating Child Node With ClassLabel=2, nexamples=780, classes=[(2, 780)]
# Creating Left Child Node With 3242 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 3242 Examples
# Creating Child Node With ClassLabel=0, nexamples=3242, classes=[(0, 3242)]
# Creating Left Child Node With 6625 Examples, and Right Node with 23375 Examples
# Creating Left Child Node With 4225 Examples, and Right Node with 2400 Examples
# Creating Left Child Node With 3175 Examples, and Right Node with 1050 Examples
# Creating Left Child Node With 919 Examples, and Right Node with 2256 Examples
# Creating Child Node With ClassLabel=2, nexamples=919, classes=[(0, 11), (2, 908)]
# Creating Child Node With ClassLabel=2, nexamples=2256, classes=[(0, 639), (2, 1617)]
# Creating Left Child Node With 145 Examples, and Right Node with 905 Examples
# Creating Child Node With ClassLabel=0, nexamples=145, classes=[(0, 145)]
# Creating Child Node With ClassLabel=0, nexamples=905, classes=[(0, 905)]
# Creating Left Child Node With 2331 Examples, and Right Node with 69 Examples
# Creating Left Child Node With 785 Examples, and Right Node with 1546 Examples
# Creating Child Node With ClassLabel=2, nexamples=785, classes=[(2, 785)]
# Creating Child Node With ClassLabel=2, nexamples=1546, classes=[(1, 3), (2, 1543)]
# Creating Left Child Node With 0 Examples, and Right Node with 69 Examples
# Creating Child Node With ClassLabel=2, nexamples=69, classes=[(2, 69)]
# Creating Left Child Node With 17511 Examples, and Right Node with 5864 Examples
# Creating Left Child Node With 11535 Examples, and Right Node with 5976 Examples
# Creating Left Child Node With 8070 Examples, and Right Node with 3465 Examples
# Creating Child Node With ClassLabel=0, nexamples=8070, classes=[(0, 4761), (1, 1280), (2, 2029)]
# Creating Child Node With ClassLabel=1, nexamples=3465, classes=[(0, 441), (1, 2965), (2, 59)]
# Creating Left Child Node With 207 Examples, and Right Node with 5769 Examples
# Creating Child Node With ClassLabel=2, nexamples=207, classes=[(1, 3), (2, 204)]
# Creating Child Node With ClassLabel=1, nexamples=5769, classes=[(0, 40), (1, 5725), (2, 4)]
# Creating Left Child Node With 1796 Examples, and Right Node with 4068 Examples
# Creating Left Child Node With 262 Examples, and Right Node with 1534 Examples
# Creating Child Node With ClassLabel=0, nexamples=262, classes=[(0, 239), (1, 23)]
# Creating Child Node With ClassLabel=0, nexamples=1534, classes=[(0, 1512), (2, 22)]
# Creating Left Child Node With 2846 Examples, and Right Node with 1222 Examples
# Creating Child Node With ClassLabel=2, nexamples=2846, classes=[(0, 1307), (2, 1539)]
# Creating Child Node With ClassLabel=2, nexamples=1222, classes=[(1, 1), (2, 1221)]
# Creating Left Child Node With 12043 Examples, and Right Node with 17957 Examples
# Creating Left Child Node With 3140 Examples, and Right Node with 8903 Examples
# Creating Left Child Node With 1791 Examples, and Right Node with 1349 Examples
# Creating Left Child Node With 670 Examples, and Right Node with 1121 Examples
# Creating Child Node With ClassLabel=0, nexamples=670, classes=[(0, 670)]
# Creating Child Node With ClassLabel=0, nexamples=1121, classes=[(0, 1067), (1, 54)]
# Creating Left Child Node With 1100 Examples, and Right Node with 249 Examples
# Creating Child Node With ClassLabel=0, nexamples=1100, classes=[(0, 1093), (2, 7)]
# Creating Child Node With ClassLabel=1, nexamples=249, classes=[(0, 3), (1, 246)]
# Creating Left Child Node With 6089 Examples, and Right Node with 2814 Examples
# Creating Left Child Node With 5964 Examples, and Right Node with 125 Examples
# Creating Child Node With ClassLabel=2, nexamples=5964, classes=[(1, 28), (2, 5936)]
# Creating Child Node With ClassLabel=2, nexamples=125, classes=[(0, 60), (2, 65)]
# Creating Left Child Node With 427 Examples, and Right Node with 2387 Examples
# Creating Child Node With ClassLabel=0, nexamples=427, classes=[(0, 427)]
# Creating Child Node With ClassLabel=0, nexamples=2387, classes=[(0, 2353), (2, 34)]
# Creating Left Child Node With 15871 Examples, and Right Node with 2086 Examples
# Creating Left Child Node With 11589 Examples, and Right Node with 4282 Examples
# Creating Left Child Node With 7097 Examples, and Right Node with 4492 Examples
# Creating Child Node With ClassLabel=0, nexamples=7097, classes=[(0, 4325), (1, 1554), (2, 1218)]
# Creating Child Node With ClassLabel=1, nexamples=4492, classes=[(1, 3923), (2, 569)]
# Creating Left Child Node With 4197 Examples, and Right Node with 85 Examples
# Creating Child Node With ClassLabel=1, nexamples=4197, classes=[(0, 2), (1, 4195)]
# Creating Child Node With ClassLabel=2, nexamples=85, classes=[(2, 85)]
# Creating Left Child Node With 0 Examples, and Right Node with 2086 Examples
# Creating Left Child Node With 1210 Examples, and Right Node with 876 Examples
# Creating Child Node With ClassLabel=2, nexamples=1210, classes=[(2, 1210)]
# Creating Child Node With ClassLabel=2, nexamples=876, classes=[(2, 876)]
# Creating Left Child Node With 20693 Examples, and Right Node with 9307 Examples
# Creating Left Child Node With 11835 Examples, and Right Node with 8858 Examples
# Creating Left Child Node With 3574 Examples, and Right Node with 8261 Examples
# Creating Left Child Node With 550 Examples, and Right Node with 3024 Examples
# Creating Child Node With ClassLabel=1, nexamples=550, classes=[(0, 5), (1, 544), (2, 1)]
# Creating Child Node With ClassLabel=2, nexamples=3024, classes=[(0, 527), (1, 78), (2, 2419)]
# Creating Left Child Node With 5369 Examples, and Right Node with 2892 Examples
# Creating Child Node With ClassLabel=1, nexamples=5369, classes=[(0, 776), (1, 4254), (2, 339)]
# Creating Child Node With ClassLabel=2, nexamples=2892, classes=[(2, 2892)]
# Creating Left Child Node With 5264 Examples, and Right Node with 3594 Examples
# Creating Left Child Node With 1452 Examples, and Right Node with 3812 Examples
# Creating Child Node With ClassLabel=0, nexamples=1452, classes=[(0, 1144), (1, 307), (2, 1)]
# Creating Child Node With ClassLabel=0, nexamples=3812, classes=[(0, 2606), (1, 1206)]
# Creating Left Child Node With 693 Examples, and Right Node with 2901 Examples
# Creating Child Node With ClassLabel=1, nexamples=693, classes=[(1, 598), (2, 95)]
# Creating Child Node With ClassLabel=1, nexamples=2901, classes=[(1, 2900), (2, 1)]
# Creating Left Child Node With 5470 Examples, and Right Node with 3837 Examples
# Creating Left Child Node With 2738 Examples, and Right Node with 2732 Examples
# Creating Left Child Node With 241 Examples, and Right Node with 2497 Examples
# Creating Child Node With ClassLabel=2, nexamples=241, classes=[(0, 18), (2, 223)]
# Creating Child Node With ClassLabel=2, nexamples=2497, classes=[(0, 34), (2, 2463)]
# Creating Left Child Node With 1248 Examples, and Right Node with 1484 Examples
# Creating Child Node With ClassLabel=0, nexamples=1248, classes=[(0, 1141), (1, 105), (2, 2)]
# Creating Child Node With ClassLabel=2, nexamples=1484, classes=[(2, 1484)]
# Creating Left Child Node With 1803 Examples, and Right Node with 2034 Examples
# Creating Left Child Node With 21 Examples, and Right Node with 1782 Examples
# Creating Child Node With ClassLabel=0, nexamples=21, classes=[(0, 13), (1, 8)]
# Creating Child Node With ClassLabel=0, nexamples=1782, classes=[(0, 1780), (2, 2)]
# Creating Left Child Node With 1056 Examples, and Right Node with 978 Examples
# Creating Child Node With ClassLabel=0, nexamples=1056, classes=[(0, 983), (2, 73)]
# Creating Child Node With ClassLabel=0, nexamples=978, classes=[(0, 973), (2, 5)]
# Creating Left Child Node With 22773 Examples, and Right Node with 7227 Examples
# Creating Left Child Node With 6207 Examples, and Right Node with 16566 Examples
# Creating Left Child Node With 3449 Examples, and Right Node with 2758 Examples
# Creating Left Child Node With 1149 Examples, and Right Node with 2300 Examples
# Creating Child Node With ClassLabel=2, nexamples=1149, classes=[(2, 1149)]
# Creating Child Node With ClassLabel=2, nexamples=2300, classes=[(0, 110), (2, 2190)]
# Creating Left Child Node With 1314 Examples, and Right Node with 1444 Examples
# Creating Child Node With ClassLabel=0, nexamples=1314, classes=[(0, 1314)]
# Creating Child Node With ClassLabel=0, nexamples=1444, classes=[(0, 1443), (2, 1)]
# Creating Left Child Node With 6192 Examples, and Right Node with 10374 Examples
# Creating Left Child Node With 5169 Examples, and Right Node with 1023 Examples
# Creating Child Node With ClassLabel=0, nexamples=5169, classes=[(0, 5009), (2, 160)]
# Creating Child Node With ClassLabel=1, nexamples=1023, classes=[(1, 1023)]
# Creating Left Child Node With 5265 Examples, and Right Node with 5109 Examples
# Creating Child Node With ClassLabel=2, nexamples=5265, classes=[(0, 2117), (1, 207), (2, 2941)]
# Creating Child Node With ClassLabel=1, nexamples=5109, classes=[(0, 2), (1, 3363), (2, 1744)]
# Creating Left Child Node With 1782 Examples, and Right Node with 5445 Examples
# Creating Left Child Node With 1579 Examples, and Right Node with 203 Examples
# Creating Left Child Node With 1094 Examples, and Right Node with 485 Examples
# Creating Child Node With ClassLabel=2, nexamples=1094, classes=[(2, 1094)]
# Creating Child Node With ClassLabel=2, nexamples=485, classes=[(1, 14), (2, 471)]
# Creating Left Child Node With 0 Examples, and Right Node with 203 Examples
# Creating Child Node With ClassLabel=2, nexamples=203, classes=[(2, 203)]
# Creating Left Child Node With 327 Examples, and Right Node with 5118 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 327 Examples
# Creating Child Node With ClassLabel=1, nexamples=327, classes=[(1, 280), (2, 47)]
# Creating Left Child Node With 3625 Examples, and Right Node with 1493 Examples
# Creating Child Node With ClassLabel=1, nexamples=3625, classes=[(0, 5), (1, 3620)]
# Creating Child Node With ClassLabel=1, nexamples=1493, classes=[(1, 1493)]

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000,) 30000
# Predicted      0     1     2    All
# Actual
# 0           9847    14   139  10000
# 1            533  9467     0  10000
# 2            798    51  9151  10000
# All        11178  9532  9290  30000

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (30000,) 15000
# Predicted     0     1     2    All
# Actual
# 0          4927     4    69   5000
# 1           282  4718     0   5000
# 2           404    24  4572   5000
# All        5613  4746  4641  15000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y.flatten() ==  np.array(Yp)) / float(Y.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_points_range(rfc,X,Y)
# Out:
# (10000, 2)
# [0, 1, 2]

# %%
t.plot_decision_regions(X,Y,rfc,res=0.1)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,40))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,Y,clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...
